# %% [raw]
# #QUESTIONS
# 1.DO DATA ANALYSIS TO FIGURE OUT WHICH VARIABLES HAVE DIRECT AND CLEAR IMPACT ON EMPLOYEE RETENTION
# 2.PLOT BAR CHARTS SHOWING IMPACT OF EMPLOYEE SALARIES ON RETENTION
# 3.PLOT BAR CHARTS SHOWING CORRELATION BETWEEN DEPARTMENT AND EMPLOYEE RETENTION
# 4.BULID LOGISTIC REGRESSION MODEL USING VARIABLES THAT WERE NARROWED DOWN IN STEP 1
# 5.MEASURE THE ACCURACY OF THE MODEL

# %%
#importing the necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
#importing the dataset
df = pd.read_csv("HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
#Cleaning the dataset
x = df.info()
y = df.isna().shape
z = df.duplicated()
x, y, z
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB
# (None,
#  (14999, 10),
#  0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  14994     True
#  14995     True
#  14996     True
# ...

# %%
categorical_data = df.select_dtypes(include = ["object"])
numerical_data = df.select_dtypes(include = ["number"])
categorical_data, numerical_data
# Out:
# (      Department  salary
#  0          sales     low
#  1          sales  medium
#  2          sales  medium
#  3          sales     low
#  4          sales     low
#  ...          ...     ...
#  14994    support     low
#  14995    support     low
#  14996    support     low
#  14997    support     low
#  14998    support     low
#
#  [14999 rows x 2 columns],
#         satisfaction_level  last_evaluation  number_project  \
#  0                    0.38             0.53               2
#  1                    0.80             0.86               5
#  2                    0.11             0.88               7
#  3                    0.72             0.87               5
#  4                    0.37             0.52               2
#  ...                   ...              ...             ...
#  14994                0.40             0.57               2
#  14995                0.37             0.48               2
#  14996                0.37             0.53               2
# ...

# %%
#...summary statistics... - numerical_data
a = df.describe(include = ["number"], exclude = ["object"])
b = numerical_data.median()
c = numerical_data.mode()
a, b, c
# Out:
# (       satisfaction_level  last_evaluation  number_project  \
#  count        14999.000000     14999.000000    14999.000000
#  mean             0.612834         0.716102        3.803054
#  std              0.248631         0.171169        1.232592
#  min              0.090000         0.360000        2.000000
#  25%              0.440000         0.560000        3.000000
#  50%              0.640000         0.720000        4.000000
#  75%              0.820000         0.870000        5.000000
#  max              1.000000         1.000000        7.000000
#
#         average_montly_hours  time_spend_company  Work_accident          left  \
#  count          14999.000000        14999.000000   14999.000000  14999.000000
#  mean             201.050337            3.498233       0.144610      0.238083
#  std               49.943099            1.460136       0.351719      0.425924
#  min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
#...One hot encoding...
le = LabelEncoder()
categorical_data_transformed = categorical_data.apply(le.fit_transform)
categorical_data_transformed
# Out:
#        Department  salary
# 0               7       1
# 1               7       2
# 2               7       2
# 3               7       1
# 4               7       1
# ...           ...     ...
# 14994           8       1
# 14995           8       1
# 14996           8       1
# 14997           8       1
# 14998           8       1
#
# [14999 rows x 2 columns]

# %%
df_updated = df.drop(columns = categorical_data.columns)
df_transformed = pd.concat([df_updated, categorical_data_transformed], axis = "columns")
df_transformed
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
#...summary statistics - categorical columns
a = categorical_data_transformed.describe()
b = categorical_data_transformed.median()
c = categorical_data_transformed.mode()
a, b, c
# Out:
# (         Department        salary
#  count  14999.000000  14999.000000
#  mean       5.870525      1.347290
#  std        2.868786      0.625819
#  min        0.000000      0.000000
#  25%        4.000000      1.000000
#  50%        7.000000      1.000000
#  75%        8.000000      2.000000
#  max        9.000000      2.000000,
#  Department    7.0
#  salary        1.0
#  dtype: float64,
#     Department  salary
#  0           7       1)

# %%
#creating regression lines for each column against leaving
X = df_transformed.drop(columns = ["left"])
y = df_transformed["left"]
correlation_matrix = df_transformed.corr()["left"].drop(["left"]).sort_values(ascending=False)
cm_mean = correlation_matrix.mean()
cm_median = correlation_matrix.median()
correlation_matrix, cm_mean, cm_median
# Out:
# (time_spend_company       0.144822
#  average_montly_hours     0.071287
#  Department               0.032105
#  number_project           0.023787
#  last_evaluation          0.006567
#  salary                  -0.001294
#  promotion_last_5years   -0.061788
#  Work_accident           -0.154622
#  satisfaction_level      -0.388375
#  Name: left, dtype: float64,
#  -0.03638994307396804,
#  0.006567120447529851)

# %%
# Employee retention - based on salary

print(df_transformed["salary"].unique())

salary_retention = df_transformed.groupby("salary")["left"].count()
fig, ax = plt.subplots(figsize = (12, 6))
salary_retention.plot(kind = "bar", alpha = 0.5, ax = ax)
for rect in ax.patches:
        height = rect.get_height()
        ax.annotate(
            f"{height:.0f}",
            xy = (rect.get_x()+rect.get_width()/2, height),
            xytext = (0, 3),
            textcoords = "offset points",
            ha = "center",
            va = "bottom"
        )
plt.xlabel("salary")        
plt.ylabel("left")        
plt.legend()        
plt.tight_layout()
plt.show()

print(df_transformed["salary"].unique())
df.salary.unique()
# Out:
# [1 2 0]
# [1 2 0]
# array(['low', 'medium', 'high'], dtype=object)

# %%
# Employee retention - based on department

print(df_transformed["Department"].unique())

salary_retention = df_transformed.groupby("Department")["left"].count()
fig, ax = plt.subplots(figsize = (12, 6))
salary_retention.plot(kind = "bar", alpha = 0.5, ax = ax)
for rect in ax.patches:
        height = rect.get_height()
        ax.annotate(
            f"{height:.0f}",
            xy = (rect.get_x()+rect.get_width()/2, height),
            xytext = (0, 3),
            textcoords = "offset points",
            ha = "center",
            va = "bottom"
        )
plt.xlabel("department")        
plt.ylabel("left")        
plt.legend()        
plt.tight_layout()
plt.show()

print(df_transformed["Department"].unique())
df.Department.unique()
# Out:
# [7 2 3 9 8 4 0 6 5 1]
# [7 2 3 9 8 4 0 6 5 1]
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
#...making a model...
