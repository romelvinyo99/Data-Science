# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
df = pd.read_csv("insurance_data.csv")
df.head(3)
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1

# %%
X = df.drop(columns = ["bought_insurance"], axis = 1)
y = df["bought_insurance"]
X_train , X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
X_train_scaled = X_train/100
X_test_scaled = X_test/100

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2, ), activation = "sigmoid", kernel_initializer = "ones", bias_initializer = "zeros")
])
model.compile(
    optimizer = "adam",
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
)
model.fit(X_train_scaled, y_train, epochs=500)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 731ms/step - accuracy: 0.5455 - loss: 0.6325
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5455 - loss: 0.6324
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5455 - loss: 0.6323
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5455 - loss: 0.6322
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5455 - loss: 0.6321
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5455 - loss: 0.6321
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5455 - loss: 0.6320
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5455 - loss: 0.6319
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5455 - loss: 0.6318
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5455 - loss: 0.6317
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5455 - loss: 0.6316
# Epoch 12/500
# ...

# %%
model.predict(X_test_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# array([[0.498281  ],
#        [0.49444902],
#        [0.5021278 ],
#        [0.61860925],
#        [0.5855718 ],
#        [0.61499995]], dtype=float32)

# %%
y_test
# Out:
# 26    0
# 0     0
# 16    1
# 15    1
# 27    0
# 6     0
# Name: bought_insurance, dtype: int64

# %%
coef, intercept = model.get_weights()
coef, intercept
# Out:
# (array([[1.5328914],
#         [1.5270585]], dtype=float32),
#  array([-0.37471157], dtype=float32))

# %%
def sigmoid_numpy(weighted_sum):
    return 1 / (1 + np.exp(-weighted_sum))


def logloss(y_predicted):
    epsilon = 1e-15
    y_predicted_new = np.clip(y_predicted, epsilon, 1-epsilon)
    return -np.mean(y_true * np.log(y_predicted_new) + (1 - y_true) * np.log(1 - y_predicted))
    
def log_loss(age, affordability, y_true, epochs, loss_threshhold):
    w1 = w2 = 1
    bias = 0
    learning_rate = 0.004
    n = len(age)
    for epoch in range(epochs):
        weighted_sum = w1 * age + w2 * affordability + bias
        y_predicted = sigmoid_numpy(weighted_sum)
        loss = logloss(y_predicted)
        w1d = (1/n) * np.dot(np.transpose(age), (y_predicted - y_true))
        w2d = (1/n) * np.dot(np.transpose(affordability), (y_predicted - y_true))
        bd = np.mean(y_predicted - y_true)
        w1 = w1 - learning_rate * w1d
        w2 = w2 - learning_rate * w2d
        print(f"w1 = {w1} w2 = {w2} epoch = {epoch} bias = {bias} cost = {loss}")
        if cost <= loss_threshhold:
            break
        return w1, w2, bias

# %%
import numpy as np

class MyNN:
    def __init__(self):
        self.w1 = 1
        self.w2 = 1
        self.bias = 0
        self.learning_rate = 0.004
    def predict(self, X_test):
        weighted_sum = self.w1 * X_test["age"] + self.w2 * X_test["affordibility"] + self.bias
        return self.sigmoid_numpy(weighted_sum)

    def fit(self, X, y, epochs, loss_threshold):
        self.w1, self.w2, self.bias = self.log_loss(X["age"], X["affordibility"], y, epochs, loss_threshold)

    def sigmoid_numpy(self, weighted_sum):
        return 1 / (1 + np.exp(-weighted_sum))  # Correct sigmoid function

    def loss(self, y_true, y_predicted):  # y_true should be passed in
        epsilon = 1e-15
        y_predicted_new = np.clip(y_predicted, epsilon, 1 - epsilon)
        return -np.mean(y_true * np.log(y_predicted_new) + (1 - y_true) * np.log(1 - y_predicted_new))

    def log_loss(self, age, affordibility, y_true, epochs, loss_threshold=0.00001):
        w1 = w2 = 1
        bias = 0
        learning_rate = 0.004
        n = len(age)
        for epoch in range(epochs):
            weighted_sum = w1 * age + w2 * affordibility + bias
            y_predicted = self.sigmoid_numpy(weighted_sum)
            loss = self.loss(y_true, y_predicted)
            
            w1d = (1/n) * np.dot(age, (y_predicted - y_true))
            w2d = (1/n) * np.dot(affordibility, (y_predicted - y_true))
            bd = np.mean(y_predicted - y_true)
            
            w1 -= learning_rate * w1d
            w2 -= learning_rate * w2d
            bias -= learning_rate * bd
            
            if epoch % 50 == 0:
                print(f"w1 = {w1} w2 = {w2} epoch = {epoch} bias = {bias} cost = {loss}")
            
            if loss <= loss_threshold:
                break
        
        return w1, w2, bias   

# Example usage
# logloss = MyNN()
# logloss.fit(X_train_scaled, y_train, epochs=100, loss_threshold=0.4631)
logloss = MyNN()
logloss.fit(X_train_scaled, y_train, epochs=100, loss_threshold = 0.4631)
# Out:
# w1 = 1.0001456090136183 w2 = 1.0000033909781476 epoch = 0 bias = -0.00022200464364215076 cost = 0.6325143424306755
# w1 = 1.0075001940618744 w2 = 1.0001742277545402 epoch = 50 bias = -0.01112661842968581 cost = 0.6316486618046984
